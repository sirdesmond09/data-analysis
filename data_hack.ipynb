# %%
import pandas  as pd

# %%
data = pd.read_csv("CDD ECONOMIC SEEFOR_FINAL.csv")
_list = data.columns.values.tolist()
_list
# Out:
# ['start',
#  'STATE',
#  'LGA',
#  'Name of SEEFOR FADAMA Community Association (SFCA)',
#  'Name of SEEFOR FADAMA User Groups (SFUG)',
#  'Type of Sub-project Enterprise',
#  'CROP PRODUCTION',
#  'FISHERY',
#  'LIVESTOCK',
#  'POULTRY',
#  'PROCESSING',
#  'MARKETING',
#  'RURAL INFRASTRUCTURE',
#  'FORESTRY',
#  'Total Cost of Sub-Project',
#  'IDA Amount',
#  'Beneficiary Contribution',
#  'Total Amount Disbursed',
#  'Date of disbursement',
#  'Status of Sub-Project',
#  'Duration of Sub-Project Implementation',
#  'Total Number of Service Providers',
#  'Total number of enterprise beneficiaries',
#  'Number of members with access to extension services',
#  'People that has access to services support by the SEEFOR FADAMA Project',
#  'People that has access to services support by the SEEFOR FADAMA Project/Capacity building services',
#  'People that has access to services support by the SEEFOR FADAMA Project/Advisory Services',
# ...

# %%
data.rename(columns = { "Number of members with access to extension services": "access to extension", 
                     "People that has access to services support by the SEEFOR FADAMA Project" : "access to project support service",
                    "People that has access to services support by the SEEFOR FADAMA Project/Capacity building services" : "access to capacity building services",
                    "People that has access to services support by the SEEFOR FADAMA Project/Advisory Services" : "access to advisory services",
                    "People that has access to services support by the SEEFOR FADAMA Project/People that have access to rural infrastructure services" : "access to rural infrastructure services",
                    "People that has access to services support by the SEEFOR FADAMA Project/Input Support" : "access to input support",
                    "Number of person employed on permanent basis (Male)" : "permanently employed males",
                     "Number of person employed on permanent basis (Female)" : "permanently employed females",
                     "Number of person employed on temporary basis (Male)" : "temporarily employed males", 
                      "Number of person employed on temporary basis (Female)" : "temporarily employed females",
                      "Number of beneficiaries under supported services : Male" : "male beneficiaries under support services",
                      "Number of beneficiaries under supported services: Female" : "female beneficiaries under support services",
                      "People that has access to services support by the SEEFOR FADAMA Project.1" : "access to project support service.1"}, inplace = True)
# data.head()

_elist = data.columns.values.tolist()
_elist
# Out:
# ['start',
#  'STATE',
#  'LGA',
#  'Name of SEEFOR FADAMA Community Association (SFCA)',
#  'Name of SEEFOR FADAMA User Groups (SFUG)',
#  'Type of Sub-project Enterprise',
#  'CROP PRODUCTION',
#  'FISHERY',
#  'LIVESTOCK',
#  'POULTRY',
#  'PROCESSING',
#  'MARKETING',
#  'RURAL INFRASTRUCTURE',
#  'FORESTRY',
#  'Total Cost of Sub-Project',
#  'IDA Amount',
#  'Beneficiary Contribution',
#  'Total Amount Disbursed',
#  'Date of disbursement',
#  'Status of Sub-Project',
#  'Duration of Sub-Project Implementation',
#  'Total Number of Service Providers',
#  'Total number of enterprise beneficiaries',
#  'access to extension',
#  'access to project support service',
#  'access to capacity building services',
#  'access to advisory services',
#  'access to rural infrastructure services',
#  'access to input support',
#  'Number of Meetings',
#  'Frequency of meetings held by Group',
#  'Average Size of Each Members’ Household',
#  'Number of Direct Beneficiaries: Male',
# ...

# %%
data.to_csv(r'C:\Users\Nnebue Chinedu D\Desktop\cleaned_CDD ECONOMIC SEEFOR_FINAL.csv')
